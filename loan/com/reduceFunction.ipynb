# %%
from functools import *
from functools import reduce

l=[1,2,3,4,5,6]

s=reduce(lambda x,y:x+y,l )

print(s)
# Out:
# 21

# %%
from functools import reduce
l=range(1,7)

s=reduce(lambda x, y: x+y, l)

print(s)
# Out:
# 21
