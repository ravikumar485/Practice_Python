# %%
d={}

print(type(d))
# Out:
# <class 'dict'>

# %%
d={1:"One",2:"Two",3:"Three",4:"Four",5:"Five"}
print(d)
# Out:
# {1: 'One', 2: 'Two', 3: 'Three', 4: 'Four', 5: 'Five'}

# %%
print(d[1])
# Out:
# One

# %%
d[1]=10
print(d)
# Out:
# {1: 10, 2: 'Two', 3: 'Three', 4: 'Four', 5: 'Five'}

# %%
print(d[100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(d[100])
#
# KeyError: 100

# %%
for key in d:
    print(key, d[key])
# Out:
# 1 10
# 2 Two
# 3 Three
# 4 Four
# 5 Five

# %%
d.get(1)
# Out:
# 10
