# %%
f=open(file="abc.txt",mode="r")

print(id(f))

print(type(f))

print(f.read())

print(f.name)
print(f.mode)

print(f.newlines)

print(f.writable)
print(f.readable)
print(f.closed)
f.close()
print(f.closed)
# Out:
# 2085757109744
# <class '_io.TextIOWrapper'>
# this is test file
# line 1
# line 2
#
# line 3
# abc.txt
# r
#
#
# <built-in method writable of _io.TextIOWrapper object at 0x000001E5A0CFC5F0>
# <built-in method readable of _io.TextIOWrapper object at 0x000001E5A0CFC5F0>
# False
# True
